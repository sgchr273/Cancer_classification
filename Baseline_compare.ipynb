# %%
import pickle
import numpy as np
def get_accur(filename):
    rd_accuracies = pickle.load(open("./Save/Round_accuracies/" + "Accuracy_for_" + filename + ".p", "rb"))
    return rd_accuracies

# %%
import os
os.getcwd()
# Out:
# '/usr/local/home/sgchr/Documents/Cancer_classification'

# %%
exper_name = "run_3000"
trail_0 = get_accur(f'{exper_name}0')
trail_1 = get_accur(f'{exper_name}1')
trail_2 = get_accur(f'{exper_name}2')
trail_3 = get_accur(f'{exper_name}3')
trail_4 = get_accur(f'{exper_name}4')
trail_5 = get_accur(f'{exper_name}5')
trail_6 = get_accur(f'{exper_name}6')
trail_7 = get_accur(f'{exper_name}7')
trail_8 = get_accur(f'{exper_name}8')
trail_9 = get_accur(f'{exper_name}9')

# %%
rand_accur_0 = trail_0['rand']
rand_accur_1 = trail_1['rand']
rand_accur_2 = trail_2['rand']
rand_accur_3 = trail_3['rand']
rand_accur_4 = trail_4['rand']
# rand_accur_5 = trail_5['rand']
# rand_accur_6 = trail_6['rand']
# rand_accur_7 = trail_7['rand']
# rand_accur_8 = trail_8['rand']
# rand_accur_9 = trail_9['rand']

# %%
rand_combined = [rand_accur_0, rand_accur_1, rand_accur_2, rand_accur_3, rand_accur_4]
rand_avg = [(a+b+c+d+e)/5 for a,b,c,d,e in zip(*rand_combined)]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming rand_combined is a list of lists containing your data
rand_combined = [rand_accur_0, rand_accur_1, rand_accur_2, rand_accur_3, rand_accur_4]

# Calculate the average
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

Badge_avg = np.mean(Badge_combined, axis = 0)



x = np.arange(len(rand_avg))

# Create the plot with a solid line
plt.plot(x, rand_avg, label='Mean', color='blue')

# Fill the area around the line to represent uncertainty
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.2, label='Uncertainty')

# Add labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Accuracy for 3000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
entropy_accur_0 = trail_0['entropy']
entropy_accur_1 = trail_1['entropy']
entropy_accur_2 = trail_2['entropy']
entropy_accur_3 = trail_3['entropy']
entropy_accur_4 = trail_4['entropy']
entropy_accur_5 = trail_5['entropy']
entropy_accur_6 = trail_6['entropy']
entropy_accur_7 = trail_7['entropy']
entropy_accur_8 = trail_8['entropy']
entropy_accur_9 = trail_9['entropy']
entropy_combined = [entropy_accur_0, entropy_accur_1, entropy_accur_2, entropy_accur_3, entropy_accur_4]
entropy_avg =[(a+b+c+d+e)/5 for a,b,c,d,e in zip(*entropy_combined)]

# %%
BAIT_accur_0 = trail_0['bait']
BAIT_accur_1 = trail_1['bait']
BAIT_accur_2 = trail_2['bait']
BAIT_accur_3 = trail_3['bait']
BAIT_accur_4 = trail_4['bait']
BAIT_accur_5 = trail_5['bait']
BAIT_accur_6 = trail_6['bait']
BAIT_accur_7 = trail_7['bait']
BAIT_accur_8 = trail_8['bait']
BAIT_accur_9 = trail_9['bait']
BAIT_combined = [BAIT_accur_0, BAIT_accur_1, BAIT_accur_2, BAIT_accur_3, BAIT_accur_4]
BAIT_avg =[(a+b+c+d+e)/5 for a,b,c,d,e in zip(*BAIT_combined)]

# %%
Badge_accur_0 = trail_0['badge']
Badge_accur_1 = trail_1['badge']
Badge_accur_2 = trail_2['badge']
Badge_accur_3 = trail_3['badge']
Badge_accur_4 = trail_4['badge']
Badge_accur_5 = trail_5['badge']
Badge_accur_6 = trail_6['badge']
Badge_accur_7 = trail_7['badge']
Badge_accur_8 = trail_8['badge']
Badge_accur_9 = trail_9['badge']
Badge_combined = [Badge_accur_0, Badge_accur_1, Badge_accur_2, Badge_accur_3, Badge_accur_4]
Badge_avg = [(a+b+c+d+e)/5 for a,b,c,d,e in zip(*BAIT_combined)]

# %%
Badge_combined = [Badge_accur_0, Badge_accur_1, Badge_accur_2, Badge_accur_3, Badge_accur_4]
Badge_avg = [(a+b+c+d+e)/5 for a,b,c,d,e in zip(*BAIT_combined)]

# %%
margin_accur_0 = trail_0['margin']
margin_accur_1 = trail_1['margin']
margin_accur_2 = trail_2['margin']
margin_accur_3 = trail_3['margin']
margin_accur_4 = trail_4['margin']
margin_accur_5 = trail_5['margin']
margin_accur_6 = trail_6['margin']
margin_accur_7 = trail_7['margin']
margin_accur_8 = trail_8['margin']
margin_accur_9 = trail_9['margin']
margin_combined = [margin_accur_0, margin_accur_1, margin_accur_2, margin_accur_3, margin_accur_4]
margin_avg = [(a+b+c+d+e)/5 for a,b,c,d,e in zip(*margin_combined)]

# %%
exper_name = "more_FMNIST"
trail_0 = get_accur(f'{exper_name}0_dispersed')
trail_1 = get_accur(f'{exper_name}1_dispersed')
trail_2 = get_accur(f'{exper_name}2_dispersed')
trail_3 = get_accur(f'{exper_name}3_dispersed')
trail_4 = get_accur(f'{exper_name}4_dispersed')
trail_5 = get_accur(f'{exper_name}5_dispersed')
trail_6 = get_accur(f'{exper_name}6_dispersed')
trail_7 = get_accur(f'{exper_name}7_dispersed')
trail_8 = get_accur(f'{exper_name}8_dispersed')
trail_9 = get_accur(f'{exper_name}9_dispersed')
trail_10 = get_accur(f'{exper_name}10_dispersed')
trail_11 = get_accur(f'{exper_name}11_dispersed')
trail_12 = get_accur(f'{exper_name}12_dispersed')
trail_13 = get_accur(f'{exper_name}13_dispersed')
trail_14 = get_accur(f'{exper_name}14_dispersed')
trail_15 = get_accur(f'{exper_name}15_dispersed')
trail_16 = get_accur(f'{exper_name}16_dispersed')
trail_17 = get_accur(f'{exper_name}17_dispersed')
trail_18 = get_accur(f'{exper_name}18_dispersed')
trail_19 = get_accur(f'{exper_name}19_dispersed')

# %%
FISH_dis_accur_0 = trail_0['FISH']
FISH_dis_accur_1 = trail_1['FISH']
FISH_dis_accur_2 = trail_2['FISH']
FISH_dis_accur_3 = trail_3['FISH']
FISH_dis_accur_4 = trail_4['FISH']
FISH_dis_accur_5 = trail_5['FISH']
FISH_dis_accur_6 = trail_6['FISH']
FISH_dis_accur_7 = trail_7['FISH']
FISH_dis_accur_8 = trail_8['FISH']
FISH_dis_accur_9 = trail_9['FISH']
FISH_dis_accur_10 = trail_10['FISH']
FISH_dis_accur_11 = trail_11['FISH']
FISH_dis_accur_12 = trail_12['FISH']
FISH_dis_accur_13 = trail_13['FISH']
FISH_dis_accur_14 = trail_14['FISH']
FISH_dis_accur_15 = trail_15['FISH']
FISH_dis_accur_16 = trail_16['FISH']
FISH_dis_accur_17 = trail_17['FISH']
FISH_dis_accur_18 = trail_18['FISH']
FISH_dis_accur_19 = trail_19['FISH']

# %%
FISH_dis_combined = [FISH_dis_accur_0, FISH_dis_accur_1, FISH_dis_accur_2, FISH_dis_accur_3, FISH_dis_accur_4,FISH_dis_accur_5, FISH_dis_accur_6, FISH_dis_accur_7, FISH_dis_accur_8, FISH_dis_accur_9,FISH_dis_accur_10, FISH_dis_accur_11, FISH_dis_accur_12, FISH_dis_accur_13, FISH_dis_accur_14,FISH_dis_accur_15, FISH_dis_accur_16, FISH_dis_accur_17, FISH_dis_accur_18, FISH_dis_accur_19]
FISH_dis_avg = [(a+b+c+d+e+f+g+h+i+j+h+k+l+m+n+o+p+q+r+s)/20 for a,b,c,d,e,f,g,h,i,j,h,k,l,m,n,o,p,q,r,s in zip(*FISH_dis_combined)]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate the average
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

Badge_avg = np.mean(Badge_combined, axis = 0)
Badge_std = np.std(Badge_combined, axis =0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)

margin_avg = np.mean(margin_combined, axis = 0)
margin_std = np.std(margin_combined, axis =0)

x = np.arange(len(rand_avg))

# Create the plot with a solid line
plt.plot(x, rand_avg, label='rand', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='green')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='green', alpha=0.1)

plt.plot(x, Badge_avg, label='Badge', color='red')
plt.fill_between(x, Badge_avg - Badge_std, Badge_avg + Badge_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, margin_avg, label='margin', color='black')
plt.fill_between(x, margin_avg - margin_std, margin_avg + margin_std, color='black', alpha=0.1)


# Add labels and legend
plt.xlabel('Active Learning Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy for 3000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(BAIT_avg, label="BAIT")
plt.plot(rand_avg, label='Rand')
plt.plot(entropy_avg, label = 'Entropy')
plt.plot(Badge_avg, label='Badge')
plt.plot(margin_avg, label='Margin')
plt.title('Accuracy for 3000 samples averged over 5 trails')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
exper_name = "r8000"
trail_0 = get_accur(f'{exper_name}0')
trail_1 = get_accur(f'{exper_name}1')
trail_2 = get_accur(f'{exper_name}2')
trail_3 = get_accur(f'{exper_name}3')
trail_4 = get_accur(f'{exper_name}4')
# trail_5 = get_accur(f'{exper_name}5')
# trail_6 = get_accur(f'{exper_name}6')
# trail_7 = get_accur(f'{exper_name}7')
# trail_8 = get_accur(f'{exper_name}8')
# trail_9 = get_accur(f'{exper_name}9')

# %%
rand_accur_0 = trail_0['rand']
rand_accur_1 = trail_1['rand']
rand_accur_2 = trail_2['rand']
rand_accur_3 = trail_3['rand']
rand_accur_4 = trail_4['rand']
rand_combined = [rand_accur_0, rand_accur_1, rand_accur_2, rand_accur_3, rand_accur_4]
rand_avg = [(a+b+c+d+e)/5 for a,b,c,d,e in zip(*rand_combined)]

# %%
entropy_accur_0 = trail_0['entropy']
entropy_accur_1 = trail_1['entropy']
entropy_accur_2 = trail_2['entropy']
entropy_accur_3 = trail_3['entropy']
entropy_accur_4 = trail_4['entropy']
# entropy_accur_5 = trail_5['entropy']
# entropy_accur_6 = trail_6['entropy']
# entropy_accur_7 = trail_7['entropy']
# entropy_accur_8 = trail_8['entropy']
# entropy_accur_9 = trail_9['entropy']
entropy_combined = [entropy_accur_0, entropy_accur_1, entropy_accur_2, entropy_accur_3, entropy_accur_4]
entropy_avg =[(a+b+c+d+e)/5 for a,b,c,d,e in zip(*entropy_combined)]

# %%
BAIT_accur_0 = trail_0['bait']
BAIT_accur_1 = trail_1['bait']
BAIT_accur_2 = trail_2['bait']
BAIT_accur_3 = trail_3['bait']
BAIT_accur_4 = trail_4['bait']
# BAIT_accur_5 = trail_5['bait']
# BAIT_accur_6 = trail_6['bait']
# BAIT_accur_7 = trail_7['bait']
# BAIT_accur_8 = trail_8['bait']
# BAIT_accur_9 = trail_9['bait']
BAIT_combined = [BAIT_accur_0, BAIT_accur_1, BAIT_accur_2, BAIT_accur_3, BAIT_accur_4]
BAIT_avg =[(a+b+c+d+e)/5 for a,b,c,d,e in zip(*BAIT_combined)]

# %%
Badge_accur_0 = trail_0['badge']
Badge_accur_1 = trail_1['badge']
Badge_accur_2 = trail_2['badge']
Badge_accur_3 = trail_3['badge']
Badge_accur_4 = trail_4['badge']
# Badge_accur_5 = trail_5['badge']
# Badge_accur_6 = trail_6['badge']
# Badge_accur_7 = trail_7['badge']
# Badge_accur_8 = trail_8['badge']
# Badge_accur_9 = trail_9['badge']
Badge_combined = [Badge_accur_0, Badge_accur_1, Badge_accur_2, Badge_accur_3, Badge_accur_4]
Badge_avg = [(a+b+c+d+e)/5 for a,b,c,d,e in zip(*BAIT_combined)]

# %%
margin_accur_0 = trail_0['margin']
margin_accur_1 = trail_1['margin']
margin_accur_2 = trail_2['margin']
margin_accur_3 = trail_3['margin']
margin_accur_4 = trail_4['margin']
# margin_accur_5 = trail_5['margin']
# margin_accur_6 = trail_6['margin']
# margin_accur_7 = trail_7['margin']
# margin_accur_8 = trail_8['margin']
# margin_accur_9 = trail_9['margin']
margin_combined = [margin_accur_0, margin_accur_1, margin_accur_2, margin_accur_3, margin_accur_4]
margin_avg = [(a+b+c+d+e)/5 for a,b,c,d,e in zip(*margin_combined)]

# %%
#5000 images
import numpy as np
import matplotlib.pyplot as plt

# Calculate the average
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

Badge_avg = np.mean(Badge_combined, axis = 0)
Badge_std = np.std(Badge_combined, axis =0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)

margin_avg = np.mean(margin_combined, axis = 0)
margin_std = np.std(margin_combined, axis =0)

x = np.arange(len(rand_avg))

# Create the plot with a solid line
plt.plot(x, rand_avg, label='rand', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='green')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='green', alpha=0.1)

plt.plot(x, Badge_avg, label='Badge', color='red')
plt.fill_between(x, Badge_avg - Badge_std, Badge_avg + Badge_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, margin_avg, label='margin', color='black')
plt.fill_between(x, margin_avg - margin_std, margin_avg + margin_std, color='black', alpha=0.1)


# Add labels and legend
plt.xlabel('Active Learning Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
#8000 images

import numpy as np
import matplotlib.pyplot as plt

# Calculate the average
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

Badge_avg = np.mean(Badge_combined, axis = 0)
Badge_std = np.std(Badge_combined, axis =0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)

margin_avg = np.mean(margin_combined, axis = 0)
margin_std = np.std(margin_combined, axis =0)

x = np.arange(len(rand_avg))

# Create the plot with a solid line
plt.plot(x, rand_avg, label='rand', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='green')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='green', alpha=0.1)

plt.plot(x, Badge_avg, label='Badge', color='red')
plt.fill_between(x, Badge_avg - Badge_std, Badge_avg + Badge_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, margin_avg, label='margin', color='black')
plt.fill_between(x, margin_avg - margin_std, margin_avg + margin_std, color='black', alpha=0.1)


# Add labels and legend
plt.xlabel('Active Learning Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy for 8000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(BAIT_avg, label="BAIT")
plt.plot(rand_avg, label='Rand')
plt.plot(entropy_avg, label = 'Entropy')
plt.plot(Badge_avg, label='Badge')
plt.plot(margin_avg, label='Margin')
plt.title('Accuracy for 5000 samples averged over 5 trails')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Specify the path to your output file
file_path = '/usr/local/home/sgchr/Documents/Cancer_classification/run_8000.out'

# Initialize a dictionary to store values for each algorithm
algorithm_data = {}

# Read and extract lines with the keyword "testing"
with open(file_path, 'r') as file:
    testing_lines = [line.strip() for line in file if 'testing' in line]

# Display the extracted lines

# with open('data.out', 'w') as file:
for line in testing_lines:
    print(line)
# Out:
# number of testing pool: 791
# 800	testing accuracy 0.6915297092288243 	 precision 1.0 	 recall 0.6956521739130435 	 f1 score 0.8205128205128205
# 1600	testing accuracy 0.5929203539823009 	 precision 0.35294117647058826 	 recall 1.0 	 f1 score 0.5217391304347826
# 2400	testing accuracy 0.8407079646017699 	 precision 0.8888888888888888 	 recall 1.0 	 f1 score 0.9411764705882353
# 3200	testing accuracy 0.8634639696586599 	 precision 1.0 	 recall 0.7222222222222222 	 f1 score 0.8387096774193548
# 4000	testing accuracy 0.561314791403287 	 precision 0.3888888888888889 	 recall 1.0 	 f1 score 0.56
# 4800	testing accuracy 0.3198482932996207 	 precision 0.0 	 recall 1.0 	 f1 score 0.0
# 5600	testing accuracy 0.8798988621997471 	 precision 1.0 	 recall 0.85 	 f1 score 0.9189189189189189
# 6400	testing accuracy 0.7496839443742098 	 precision 0.6 	 recall 1.0 	 f1 score 0.7499999999999999
# 7200	testing accuracy 0.5752212389380531 	 precision 0.375 	 recall 1.0 	 f1 score 0.5454545454545454
# ...

# %%
# Provided text
text_data = """
800	testing accuracy 0.6915297092288243 	 precision 1.0 	 recall 0.782608695652174 	 f1 score 0.878048780487805
1600	testing accuracy 0.6599241466498104 	 precision 0.75 	 recall 0.8181818181818182 	 f1 score 0.7826086956521738
2400	testing accuracy 0.7041719342604298 	 precision 1.0 	 recall 0.5217391304347826 	 f1 score 0.6857142857142856
3200	testing accuracy 0.8369152970922883 	 precision 0.7857142857142857 	 recall 1.0 	 f1 score 0.88
4000	testing accuracy 0.8166877370417194 	 precision 0.9411764705882353 	 recall 0.8 	 f1 score 0.8648648648648648
4800	testing accuracy 0.7130214917825537 	 precision 0.6428571428571429 	 recall 1.0 	 f1 score 0.782608695652174
5600	testing accuracy 0.729456384323641 	 precision 0.9375 	 recall 0.7894736842105263 	 f1 score 0.8571428571428572
6400	testing accuracy 0.8609355246523388 	 precision 0.8333333333333334 	 recall 1.0 	 f1 score 0.9090909090909091
7200	testing accuracy 0.865992414664981 	 precision 0.8823529411764706 	 recall 0.8823529411764706 	 f1 score 0.8823529411764706
8000	testing accuracy 0.5878634639696586 	 precision 0.3125 	 recall 1.0 	 f1 score 0.47619047619047616
800	testing accuracy 0.6915297092288243 	 precision 1.0 	 recall 0.6521739130434783 	 f1 score 0.7894736842105263
1600	testing accuracy 0.7800252844500632 	 precision 0.95 	 recall 0.9047619047619048 	 f1 score 0.9268292682926829
2400	testing accuracy 0.7433628318584071 	 precision 1.0 	 recall 0.5714285714285714 	 f1 score 0.7272727272727273
3200	testing accuracy 0.7079646017699115 	 precision 1.0 	 recall 0.6521739130434783 	 f1 score 0.7894736842105263
4000	testing accuracy 0.6852085967130215 	 precision 0.4444444444444444 	 recall 0.8888888888888888 	 f1 score 0.5925925925925926
4800	testing accuracy 0.7130214917825537 	 precision 1.0 	 recall 0.782608695652174 	 f1 score 0.878048780487805
5600	testing accuracy 0.8343868520859671 	 precision 1.0 	 recall 0.9411764705882353 	 f1 score 0.9696969696969697
6400	testing accuracy 0.7319848293299621 	 precision 0.8235294117647058 	 recall 0.9333333333333333 	 f1 score 0.8749999999999999
7200	testing accuracy 0.7774968394437421 	 precision 1.0 	 recall 0.5 	 f1 score 0.6666666666666666
8000	testing accuracy 0.3084702907711757 	 precision 0.0 	 recall 1.0 	 f1 score 0.0
800	testing accuracy 0.3084702907711757 	 precision 0.0 	 recall 1.0 	 f1 score 0.0
1600	testing accuracy 0.843236409608091 	 precision 0.6923076923076923 	 recall 0.8181818181818182 	 f1 score 0.7500000000000001
2400	testing accuracy 0.6814159292035398 	 precision 0.875 	 recall 0.7 	 f1 score 0.7777777777777777
3200	testing accuracy 0.3109987357774968 	 precision 0.0 	 recall 1.0 	 f1 score 0.0
4000	testing accuracy 0.6814159292035398 	 precision 0.5555555555555556 	 recall 1.0 	 f1 score 0.7142857142857143
4800	testing accuracy 0.8027812895069533 	 precision 0.9444444444444444 	 recall 1.0 	 f1 score 0.9714285714285714
5600	testing accuracy 0.7332490518331226 	 precision 1.0 	 recall 0.45454545454545453 	 f1 score 0.625
6400	testing accuracy 0.5790139064475348 	 precision 0.5882352941176471 	 recall 1.0 	 f1 score 0.7407407407407407
7200	testing accuracy 0.4639696586599241 	 precision 0.125 	 recall 0.6666666666666666 	 f1 score 0.21052631578947367
8000	testing accuracy 0.7850821744627055 	 precision 0.6875 	 recall 0.8461538461538461 	 f1 score 0.7586206896551724
800	testing accuracy 0.6915297092288243 	 precision 1.0 	 recall 0.5652173913043478 	 f1 score 0.7222222222222222
1600	testing accuracy 0.8584070796460177 	 precision 0.9375 	 recall 1.0 	 f1 score 0.967741935483871
2400	testing accuracy 0.809102402022756 	 precision 0.9230769230769231 	 recall 0.75 	 f1 score 0.8275862068965517
3200	testing accuracy 0.6877370417193426 	 precision 0.8571428571428571 	 recall 0.9 	 f1 score 0.8780487804878048
4000	testing accuracy 0.6940581542351454 	 precision 1.0 	 recall 0.6086956521739131 	 f1 score 0.7567567567567568
4800	testing accuracy 0.695322376738306 	 precision 0.6 	 recall 0.6666666666666666 	 f1 score 0.631578947368421
5600	testing accuracy 0.4740834386852086 	 precision 0.23076923076923078 	 recall 0.75 	 f1 score 0.3529411764705882
6400	testing accuracy 0.450063211125158 	 precision 0.1875 	 recall 0.75 	 f1 score 0.3
7200	testing accuracy 0.31352718078381797 	 precision 0.0 	 recall 1.0 	 f1 score 0.0
8000	testing accuracy 0.8394437420986094 	 precision 0.8125 	 recall 0.7222222222222222 	 f1 score 0.7647058823529411
800	testing accuracy 0.6915297092288243 	 precision 1.0 	 recall 0.782608695652174 	 f1 score 0.878048780487805
1600	testing accuracy 0.7130214917825537 	 precision 0.7058823529411765 	 recall 1.0 	 f1 score 0.8275862068965517
2400	testing accuracy 0.8811630847029077 	 precision 1.0 	 recall 0.8947368421052632 	 f1 score 0.9444444444444444
3200	testing accuracy 0.820480404551201 	 precision 0.7647058823529411 	 recall 0.9285714285714286 	 f1 score 0.8387096774193549
4000	testing accuracy 0.5360303413400759 	 precision 0.375 	 recall 1.0 	 f1 score 0.5454545454545454
4800	testing accuracy 0.6093552465233881 	 precision 0.6666666666666666 	 recall 0.7272727272727273 	 f1 score 0.6956521739130435
5600	testing accuracy 0.8811630847029077 	 precision 0.8571428571428571 	 recall 0.75 	 f1 score 0.7999999999999999
6400	testing accuracy 0.33122629582806573 	 precision 0.0 	 recall 1.0 	 f1 score 0.0
7200	testing accuracy 0.4247787610619469 	 precision 0.25 	 recall 1.0 	 f1 score 0.4
8000	testing accuracy 0.7016434892541087 	 precision 1.0 	 recall 0.6956521739130435 	 f1 score 0.8205128205128205

"""

# Split the text into lines
lines = text_data.strip().split('\n')

# Initialize lists to store precision, recall, and f1 score values
precision_values = []
recall_values = []
f1_score_values = []
# Process every tenth line
# for j in range(0,10):
for i in range(4, len(lines), 10):
    line = lines[i].split()
    pre_idx = line.index('precision') 
    precision = float(line[pre_idx + 1])
    precision_values.append(precision)
    mean_precision = sum(precision_values) / len(precision_values)
    recall_index = line.index('recall')
    recall = float(line[recall_index + 1])
    recall_values.append(recall)
    mean_recall = sum(recall_values) / len(recall_values)
    f1_score_index = line.index('score')
    f1_score = float(line[f1_score_index + 1])
    f1_score_values.append(f1_score)
    mean_f1_score = sum(f1_score_values) / len(f1_score_values)
    print(line)
        # BAIT_dict  = [{'Round': j, 'Metrics': {'Precision': mean_precision, 'Recall': mean_recall, 'F1 score': mean_f1_score}}]

# # Print the mean values
print(f"Mean Precision: {mean_precision}")
print(f"Mean Recall: {mean_recall}")
print(f"Mean F1 Score: {mean_f1_score}")
# Out:
# ['4000', 'testing', 'accuracy', '0.8166877370417194', 'precision', '0.9411764705882353', 'recall', '0.8', 'f1', 'score', '0.8648648648648648']
# ['4000', 'testing', 'accuracy', '0.6852085967130215', 'precision', '0.4444444444444444', 'recall', '0.8888888888888888', 'f1', 'score', '0.5925925925925926']
# ['4000', 'testing', 'accuracy', '0.6814159292035398', 'precision', '0.5555555555555556', 'recall', '1.0', 'f1', 'score', '0.7142857142857143']
# ['4000', 'testing', 'accuracy', '0.6940581542351454', 'precision', '1.0', 'recall', '0.6086956521739131', 'f1', 'score', '0.7567567567567568']
# ['4000', 'testing', 'accuracy', '0.5360303413400759', 'precision', '0.375', 'recall', '1.0', 'f1', 'score', '0.5454545454545454']
# Mean Precision: 0.6632352941176471
# Mean Recall: 0.8595169082125604
# Mean F1 Score: 0.6947908947908948

# %%
import pickle
BAIT_dict = []
rand_dict = []
margin_dict= []
Badge_dict = []
entropy_dict = []


for j in range(0, 10):
    precision_values = []
    recall_values = []
    f1_score_values = []

    for i in range(j, len(lines), 10):
        line = lines[i].split()
        pre_idx = line.index('precision') 
        precision = float(line[pre_idx + 1])
        precision_values.append(precision)
        
        mean_precision = sum(precision_values) / len(precision_values)
        
        recall_index = line.index('recall')
        recall = float(line[recall_index + 1])
        recall_values.append(recall)
        
        mean_recall = sum(recall_values) / len(recall_values)
        
        f1_score_index = line.index('score')
        f1_score = float(line[f1_score_index + 1])
        f1_score_values.append(f1_score)
        
        mean_f1_score = sum(f1_score_values) / len(f1_score_values)
        
        print(line)

    entropy_dict.append({'Round': j, 'Metrics': {'Precision': mean_precision, 'Recall': mean_recall, 'F1 score': mean_f1_score}})
filename ='data_val'

# with open("./Save/Round_metrics/" + filename+ '.p', 'w') as file:
#     for item in entropy_dict:
#         file.write(str(item) + '\n')
# Out:
# ['800', 'testing', 'accuracy', '0.6915297092288243', 'precision', '1.0', 'recall', '0.782608695652174', 'f1', 'score', '0.878048780487805']
# ['800', 'testing', 'accuracy', '0.6915297092288243', 'precision', '1.0', 'recall', '0.6521739130434783', 'f1', 'score', '0.7894736842105263']
# ['800', 'testing', 'accuracy', '0.3084702907711757', 'precision', '0.0', 'recall', '1.0', 'f1', 'score', '0.0']
# ['800', 'testing', 'accuracy', '0.6915297092288243', 'precision', '1.0', 'recall', '0.5652173913043478', 'f1', 'score', '0.7222222222222222']
# ['800', 'testing', 'accuracy', '0.6915297092288243', 'precision', '1.0', 'recall', '0.782608695652174', 'f1', 'score', '0.878048780487805']
# ['1600', 'testing', 'accuracy', '0.6599241466498104', 'precision', '0.75', 'recall', '0.8181818181818182', 'f1', 'score', '0.7826086956521738']
# ['1600', 'testing', 'accuracy', '0.7800252844500632', 'precision', '0.95', 'recall', '0.9047619047619048', 'f1', 'score', '0.9268292682926829']
# ...

# %%
BAIT_dict
# Out:
# [{'Round': 0,
#   'Metrics': {'Precision': 0.8,
#    'Recall': 0.7391304347826088,
#    'F1 score': 0.6433486522960207}},
#  {'Round': 1,
#   'Metrics': {'Precision': 0.793188854489164,
#    'Recall': 0.8766188197767146,
#    'F1 score': 0.79065712399967}},
#  {'Round': 2,
#   'Metrics': {'Precision': 0.6732399626517274,
#    'Recall': 0.9634920634920634,
#    'F1 score': 0.7721933151071523}},
#  {'Round': 3,
#   'Metrics': {'Precision': 0.7073076923076924,
#    'Recall': 0.8513708513708513,
#    'F1 score': 0.6919112079458263}},
#  {'Round': 4,
#   'Metrics': {'Precision': 0.6958169934640523,
#    'Recall': 0.7983333333333333,
#    'F1 score': 0.6939565217391304}},
#  {'Round': 5,
#   'Metrics': {'Precision': 0.6050125313283209,
#    'Recall': 0.8561853351327036,
#    'F1 score': 0.5823039215686274}},
#  {'Round': 6,
#   'Metrics': {'Precision': 0.5137039431157078,
#    'Recall': 0.9392307692307693,
#    'F1 score': 0.5655715866242182}},
#  {'Round': 7,
# ...

# %%
entropy_dict
# Out:
# [{'Round': 0,
#   'Metrics': {'Precision': 0.8,
#    'Recall': 0.7565217391304347,
#    'F1 score': 0.6535586934816717}},
#  {'Round': 1,
#   'Metrics': {'Precision': 0.8071380090497737,
#    'Recall': 0.9082251082251084,
#    'F1 score': 0.8509532212650559}},
#  {'Round': 2,
#   'Metrics': {'Precision': 0.9596153846153846,
#    'Recall': 0.6875809087937234,
#    'F1 score': 0.7925590884211573}},
#  {'Round': 3,
#   'Metrics': {'Precision': 0.6815126050420168,
#    'Recall': 0.8961490683229814,
#    'F1 score': 0.6772464284235372}},
#  {'Round': 4,
#   'Metrics': {'Precision': 0.6632352941176471,
#    'Recall': 0.8595169082125604,
#    'F1 score': 0.6947908947908948}},
#  {'Round': 5,
#   'Metrics': {'Precision': 0.7707936507936507,
#    'Recall': 0.8353096179183135,
#    'F1 score': 0.791863433770003}},
#  {'Round': 6,
#   'Metrics': {'Precision': 0.8050824175824175,
#    'Recall': 0.7370391218688432,
#    'F1 score': 0.720956200662083}},
#  {'Round': 7,
# ...

# %%
entropy_dict =[{'Round': 0,
  'Metrics': {'Precision': 0.8,
   'Recall': 0.7565217391304347,
   'F1 score': 0.6535586934816717}},
 {'Round': 1,
  'Metrics': {'Precision': 0.8071380090497737,
   'Recall': 0.9082251082251084,
   'F1 score': 0.8509532212650559}},
 {'Round': 2,
  'Metrics': {'Precision': 0.9596153846153846,
   'Recall': 0.6875809087937234,
   'F1 score': 0.7925590884211573}},
 {'Round': 3,
  'Metrics': {'Precision': 0.6815126050420168,
   'Recall': 0.8961490683229814,
   'F1 score': 0.6772464284235372}}]


BAIT = [{'Round': 0,
  'Metrics': {'Precision': 0.8,
   'Recall': 0.7391304347826088,
   'F1 score': 0.6433486522960207}},
 {'Round': 1,
  'Metrics': {'Precision': 0.793188854489164,
   'Recall': 0.8766188197767146,
   'F1 score': 0.79065712399967}},
 {'Round': 2,
  'Metrics': {'Precision': 0.6732399626517274,
   'Recall': 0.9634920634920634,
   'F1 score': 0.7721933151071523}},
 {'Round': 3,
  'Metrics': {'Precision': 0.7073076923076924,
   'Recall': 0.8513708513708513,
   'F1 score': 0.6919112079458263}}]

# %%
Badge_dict
# Out:
# []

# %%
{'EntropySampling': {'Round': {1: {'Precision': {.8}, 'Recall':{.73}, 'F1 score': {.64}},
   2: {'Precision': {.79}, 'Recall':{.87}, 'F1 score': {.79}},
   3: {'Precision': {.70}, 'Recall':{.85}, 'F1 score': {.69}},
   4: {'Precision': {.69}, 'Recall':{.79}, 'F1 score': {.60}},
   5: {'Precision': {.60}, 'Recall':{.85}, 'F1 score': {.58}},
   6: {'Precision': {.51}, 'Recall':{.93}, 'F1 score': {.56}},
   7: {'Precision': {.66}, 'Recall':{.82}, 'F1 score': {.66}},
   8: {'Precision': {.61}, 'Recall':{.90}, 'F1 score': {.64}},
   9: {'Precision': {.51}, 'Recall':{.98}, 'F1 score': {.59}}}}}
# Out:
# {'EntropySampling': {'Round': {1: {'Precision': {0.8},
#     'Recall': {0.73},
#     'F1 score': {0.64}},
#    2: {'Precision': {0.79}, 'Recall': {0.87}, 'F1 score': {0.79}},
#    3: {'Precision': {0.7}, 'Recall': {0.85}, 'F1 score': {0.69}},
#    4: {'Precision': {0.69}, 'Recall': {0.79}, 'F1 score': {0.6}},
#    5: {'Precision': {0.6}, 'Recall': {0.85}, 'F1 score': {0.58}},
#    6: {'Precision': {0.51}, 'Recall': {0.93}, 'F1 score': {0.56}},
#    7: {'Precision': {0.66}, 'Recall': {0.82}, 'F1 score': {0.66}},
#    8: {'Precision': {0.61}, 'Recall': {0.9}, 'F1 score': {0.64}},
#    9: {'Precision': {0.51}, 'Recall': {0.98}, 'F1 score': {0.59}}}}}

# %%
import pickle
# savefile = open("./Save/Round_metrics/data_val.p", "br")
# metrics = pickle.load(savefile)

with open("/usr/local/home/sgchr/Documents/Cancer_classification/Save/Round_metrics/data_val.p", "br") as file:
    for item in file:
        loaded_data = file.read(item + '\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/home/sgchr/Documents/Cancer_classification/Baseline_compare.ipynb Cell 34 line 7
#       <a href='vscode-notebook-cell://ssh-remote%2Br11ast8hv.managed.mst.edu/usr/local/home/sgchr/Documents/Cancer_classification/Baseline_compare.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> with open("/usr/local/home/sgchr/Documents/Cancer_classification/Save/Round_metrics/data_val.p", "br") as file:
#       <a href='vscode-notebook-cell://ssh-remote%2Br11ast8hv.managed.mst.edu/usr/local/home/sgchr/Documents/Cancer_classification/Baseline_compare.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     for item in file:
# ...

# %%
# !pwd
# Out:
# /usr/local/home/sgchr/Documents/Cancer_classification

# %%
precision_values = []
recall_values = []
f1_score_values = []

for i in range(10):
    line = lines[i].split()
    pre_idx = line.index('precision') 
    precision = float(line[pre_idx + 1])
    precision_values.append(precision)
    mean_precision = sum(precision_values) / len(precision_values)
    recall_index = line.index('recall')
    recall = float(line[recall_index + 1])
    recall_values.append(recall)
    mean_recall = sum(recall_values) / len(recall_values)
    f1_score_index = line.index('score')
    f1_score = float(line[f1_score_index + 1])
    f1_score_values.append(f1_score)
    mean_f1_score = sum(f1_score_values) / len(f1_score_values)
    print(line)
# Out:
# ['800', 'testing', 'accuracy', '0.6915297092288243', 'precision', '1.0', 'recall', '0.6956521739130435', 'f1', 'score', '0.8205128205128205']
# ['1600', 'testing', 'accuracy', '0.5929203539823009', 'precision', '0.35294117647058826', 'recall', '1.0', 'f1', 'score', '0.5217391304347826']
# ['2400', 'testing', 'accuracy', '0.8407079646017699', 'precision', '0.8888888888888888', 'recall', '1.0', 'f1', 'score', '0.9411764705882353']
# ['3200', 'testing', 'accuracy', '0.8634639696586599', 'precision', '1.0', 'recall', '0.7222222222222222', 'f1', 'score', '0.8387096774193548']
# ['4000', 'testing', 'accuracy', '0.561314791403287', 'precision', '0.3888888888888889', 'recall', '1.0', 'f1', 'score', '0.56']
# ['4800', 'testing', 'accuracy', '0.3198482932996207', 'precision', '0.0', 'recall', '1.0', 'f1', 'score', '0.0']
# ['5600', 'testing', 'accuracy', '0.8798988621997471', 'precision', '1.0', 'recall', '0.85', 'f1', 'score', '0.9189189189189189']
# ...

# %%
algorithm_data
# Out:
# {'EntropySampling': {'Trails': {1: {'Metrics': {}},
#    2: {'Metrics': {}},
#    3: {'Metrics': {}},
#    4: {'Metrics': {}},
#    5: {'Metrics': {}},
#    6: {'Metrics': {}},
#    7: {'Metrics': {}},
#    8: {'Metrics': {}},
#    9: {'Metrics': {}}}}}

# %%
parts
# Out:
# ['ValueError:',
#  'attempt',
#  'to',
#  'get',
#  'argmin',
#  'of',
#  'an',
#  'empty',
#  'sequence']
